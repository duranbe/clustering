# %%
import numpy as np
import matplotlib.pyplot as plt
from clustering import KMean

# %%
#https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
mu, sigma = 0,5 # mean and standard deviation
s = np.random.normal(mu, sigma,(100,2))

# %%
plt.scatter(s[:,0],s[:,1])

# %%
model = KMean(s,3,distance='euclidean')

# %%
model.run(n_iter=10)

# %%
model.middles
# Out:
# array([[ 5.22322798,  0.33736532],
#        [-3.3963435 ,  1.68594821],
#        [-0.83868078, -6.1923872 ]])
